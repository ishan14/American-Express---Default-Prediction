# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/amex-default-prediction/sample_submission.csv
# /kaggle/input/amex-default-prediction/train_data.csv
# /kaggle/input/amex-default-prediction/test_data.csv
# /kaggle/input/amex-default-prediction/train_labels.csv
# /kaggle/input/amex-credit/918_features_wo_imputation_2.parquet
# /kaggle/input/amex-credit/918_features_wo_imputation.parquet
# /kaggle/input/amexfeather/test_data_f32.ftr
# /kaggle/input/amexfeather/train_data.ftr
# /kaggle/input/amexfeather/train_data_f32.ftr
# /kaggle/input/amexfeather/test_data.ftr

# %%
train = pd.read_parquet("/kaggle/input/amex-credit/918_features_wo_imputation_2.parquet")

# %%
import cudf

train=cudf.read_parquet("/kaggle/input/amex-credit/918_features_wo_imputation_2.parquet")

# %%
FEATURES = train.columns[1:-1]

# %%
from sklearn.model_selection import KFold
import xgboost as xgb
import gc

# %%
SEED = 42
xgb_parms = {'max_depth': 4,
             'learning_rate':0.05,
             'subsample': 0.8,
             'colsample_bytree': 0.6,
             'eval_metric':'logloss',
             'objective': 'binary:logistic',
             'tree_method': 'gpu_hist',
             'predictor': 'gpu_predictor',
             'random_state': SEED}

# %%
class IterLoadForDMatrix(xgb.core.DataIter):
    def __init__(self, df=None, features=None, target=None, batch_size=256*1024):
        self.features = features
        self.target = target
        self.df = df
        self.it = 0 # set iterator to 0
        self.batch_size = batch_size
        self.batches = int( np.ceil( len(df) / self.batch_size ) )
        super().__init__()

    def reset(self):
        '''Reset the iterator'''
        self.it = 0

    def next(self, input_data):
        '''Yield next batch of data.'''
        if self.it == self.batches:
            return 0 # Return 0 when there's no more batch.
        
        a = self.it * self.batch_size
        b = min( (self.it + 1) * self.batch_size, len(self.df) )
        dt = cudf.DataFrame(self.df.iloc[a:b])
        input_data(data=dt[self.features], label=dt[self.target]) #, weight=dt['weight'])
        self.it += 1
        return 1

# %%
def amex_metric_mod(y_true, y_pred):

    labels     = np.transpose(np.array([y_true, y_pred]))
    labels     = labels[labels[:, 1].argsort()[::-1]]
    weights    = np.where(labels[:,0]==0, 20, 1)
    cut_vals   = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four   = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])

    gini = [0,0]
    for i in [1,0]:
        labels         = np.transpose(np.array([y_true, y_pred]))
        labels         = labels[labels[:, i].argsort()[::-1]]
        weight         = np.where(labels[:,0]==0, 20, 1)
        weight_random  = np.cumsum(weight / np.sum(weight))
        total_pos      = np.sum(labels[:, 0] *  weight)
        cum_pos_found  = np.cumsum(labels[:, 0] * weight)
        lorentz        = cum_pos_found / total_pos
        gini[i]        = np.sum((lorentz - weight_random) * weight)

    return 0.5 * (gini[1]/gini[0] + top_four)

# %%
importances = []
oof = []
train = train.to_pandas()
TRAIN_SUBSAMPLE = 1.0
gc.collect()

FOLDS = 5
SEED = 42
skf = KFold(n_splits = FOLDS, shuffle = True, random_state = SEED)

for fold, (train_idx, valid_idx) in enumerate(skf.split(train, train.target)):
    
    if TRAIN_SUBSAMPLE < 1.0:
        np.random.seed(SEED)
        train_idx = np.random.choice(train_idx, int(len(train_idx) * TRAIN_SUBSAMPLE), replace = False)
        np.random.seed(SEED)
    
    print('#'*25)
    print('### Fold', fold+1)
    print('### Train size',len(train_idx),'Valid size',len(valid_idx))
    print(f'### Training with {int(TRAIN_SUBSAMPLE*100)}% fold data...')
    print('#'*25)
    
    Xy_train = IterLoadForDMatrix(train.loc[train_idx], FEATURES, 'target')
    X_valid = train.loc[valid_idx, FEATURES]
    y_valid = train.loc[valid_idx, 'target']
        
    dtrain = xgb.DeviceQuantileDMatrix(Xy_train, max_bin=256, enable_categorical=True)
    dvalid = xgb.DMatrix(data=X_valid, label=y_valid)
    
    model = xgb.train(xgb_parms, 
                      dtrain = dtrain,
                      evals = [(dtrain, 'train'), (dvalid, 'valid')],
                      num_boost_round = 9999,
                      early_stopping_rounds = 100,
                      verbose_eval = 100)
    model.save_model(f'XBG_918_features_wo_imputation_fold{fold}.xgb')
    
    dd = model.get_score(importance_type = 'weight')
    df = pd.DataFrame({'feature': dd.keys(), f'importance_{fold}': dd.values()})
    importances.append(df)
    
    oof_preds = model.predict(dvalid)
    acc = amex_metric_mod(y_valid.values, oof_preds)
    print('Kaggle Metric = ', acc, '\n')
    
    df = train.loc[valid_idx, ['customer_ID', 'target']].copy()
    df['oof_pred'] = oof_preds
    oof.append(df)
    
    del dtrain, Xy_train, dd, df
    del X_valid, y_valid, dvalid, model
    _ = gc.collect()
    
print('#'*25)
oof = pd.concat(oof, axis=0, ignore_index=True).set_index('customer_ID')
acc = amex_metric_mod(oof.target.values, oof.oof_pred.values)
print('OVERALL CV Kaggle Metric = ', acc)
# Out:
# #########################
# ### Fold 1
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-logloss:0.66266	valid-logloss:0.66266
# [100]	train-logloss:0.23641	valid-logloss:0.23936
# [200]	train-logloss:0.22186	valid-logloss:0.22752
# [300]	train-logloss:0.21573	valid-logloss:0.22382
# [400]	train-logloss:0.21146	valid-logloss:0.22191
# [500]	train-logloss:0.20802	valid-logloss:0.22088
# [600]	train-logloss:0.20498	valid-logloss:0.22018
# [700]	train-logloss:0.20224	valid-logloss:0.21979
# [800]	train-logloss:0.19956	valid-logloss:0.21949
# [900]	train-logloss:0.19709	valid-logloss:0.21934
# [1000]	train-logloss:0.19469	valid-logloss:0.21915
# [1100]	train-logloss:0.19241	valid-logloss:0.21902
# [1200]	train-logloss:0.19017	valid-logloss:0.21897
# [1300]	train-logloss:0.18795	valid-logloss:0.21894
# [1400]	train-logloss:0.18585	valid-logloss:0.21888
# [1500]	train-logloss:0.18380	valid-logloss:0.21885
# [1600]	train-logloss:0.18179	valid-logloss:0.21882
# [1659]	train-logloss:0.18064	valid-logloss:0.21882
# Kaggle Metric =  0.7907083486615383
#
# #########################
# ### Fold 2
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-logloss:0.66267	valid-logloss:0.66267
# [100]	train-logloss:0.23632	valid-logloss:0.23848
# [200]	train-logloss:0.22182	valid-logloss:0.22659
# [300]	train-logloss:0.21562	valid-logloss:0.22280
# [400]	train-logloss:0.21137	valid-logloss:0.22082
# [500]	train-logloss:0.20802	valid-logloss:0.21975
# [600]	train-logloss:0.20506	valid-logloss:0.21914
# [700]	train-logloss:0.20233	valid-logloss:0.21870
# [800]	train-logloss:0.19979	valid-logloss:0.21850
# [900]	train-logloss:0.19735	valid-logloss:0.21832
# [1000]	train-logloss:0.19497	valid-logloss:0.21820
# [1100]	train-logloss:0.19262	valid-logloss:0.21805
# [1200]	train-logloss:0.19045	valid-logloss:0.21801
# [1300]	train-logloss:0.18828	valid-logloss:0.21795
# [1400]	train-logloss:0.18618	valid-logloss:0.21792
# [1469]	train-logloss:0.18475	valid-logloss:0.21794
# Kaggle Metric =  0.79139731359249
#
# #########################
# ### Fold 3
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-logloss:0.66270	valid-logloss:0.66259
# [100]	train-logloss:0.23706	valid-logloss:0.23622
# [200]	train-logloss:0.22256	valid-logloss:0.22426
# [300]	train-logloss:0.21635	valid-logloss:0.22058
# [400]	train-logloss:0.21210	valid-logloss:0.21868
# [500]	train-logloss:0.20871	valid-logloss:0.21777
# [600]	train-logloss:0.20574	valid-logloss:0.21712
# [700]	train-logloss:0.20294	valid-logloss:0.21667
# [800]	train-logloss:0.20029	valid-logloss:0.21635
# [900]	train-logloss:0.19777	valid-logloss:0.21609
# [1000]	train-logloss:0.19546	valid-logloss:0.21600
# [1100]	train-logloss:0.19314	valid-logloss:0.21589
# [1200]	train-logloss:0.19093	valid-logloss:0.21587
# [1300]	train-logloss:0.18877	valid-logloss:0.21581
# [1400]	train-logloss:0.18664	valid-logloss:0.21576
# [1500]	train-logloss:0.18453	valid-logloss:0.21566
# [1600]	train-logloss:0.18242	valid-logloss:0.21563
# [1700]	train-logloss:0.18045	valid-logloss:0.21564
# [1800]	train-logloss:0.17848	valid-logloss:0.21562
# [1846]	train-logloss:0.17761	valid-logloss:0.21561
# Kaggle Metric =  0.7938998646083191
#
# #########################
# ### Fold 4
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-logloss:0.66263	valid-logloss:0.66271
# [100]	train-logloss:0.23622	valid-logloss:0.23941
# [200]	train-logloss:0.22185	valid-logloss:0.22741
# [300]	train-logloss:0.21566	valid-logloss:0.22346
# [400]	train-logloss:0.21147	valid-logloss:0.22152
# [500]	train-logloss:0.20811	valid-logloss:0.22043
# [600]	train-logloss:0.20510	valid-logloss:0.21967
# [700]	train-logloss:0.20233	valid-logloss:0.21921
# [800]	train-logloss:0.19979	valid-logloss:0.21890
# [900]	train-logloss:0.19731	valid-logloss:0.21876
# [1000]	train-logloss:0.19491	valid-logloss:0.21859
# [1100]	train-logloss:0.19263	valid-logloss:0.21846
# [1200]	train-logloss:0.19043	valid-logloss:0.21834
# [1300]	train-logloss:0.18826	valid-logloss:0.21831
# [1400]	train-logloss:0.18615	valid-logloss:0.21824
# [1500]	train-logloss:0.18409	valid-logloss:0.21830
# [1508]	train-logloss:0.18394	valid-logloss:0.21830
# Kaggle Metric =  0.7876603617825941
#
# #########################
# ### Fold 5
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-logloss:0.66259	valid-logloss:0.66276
# [100]	train-logloss:0.23593	valid-logloss:0.24145
# [200]	train-logloss:0.22152	valid-logloss:0.22941
# [300]	train-logloss:0.21529	valid-logloss:0.22536
# [400]	train-logloss:0.21113	valid-logloss:0.22348
# [500]	train-logloss:0.20773	valid-logloss:0.22233
# [600]	train-logloss:0.20467	valid-logloss:0.22155
# [700]	train-logloss:0.20189	valid-logloss:0.22109
# [800]	train-logloss:0.19942	valid-logloss:0.22079
# [900]	train-logloss:0.19692	valid-logloss:0.22058
# [1000]	train-logloss:0.19458	valid-logloss:0.22041
# [1100]	train-logloss:0.19224	valid-logloss:0.22034
# [1200]	train-logloss:0.19004	valid-logloss:0.22026
# [1300]	train-logloss:0.18784	valid-logloss:0.22015
# [1400]	train-logloss:0.18571	valid-logloss:0.22007
# [1500]	train-logloss:0.18364	valid-logloss:0.22001
# [1600]	train-logloss:0.18157	valid-logloss:0.21997
# [1700]	train-logloss:0.17953	valid-logloss:0.21997
# [1739]	train-logloss:0.17875	valid-logloss:0.22001
# Kaggle Metric =  0.7919488483874008
#
# #########################
# OVERALL CV Kaggle Metric =  0.7910548624473521
